# %% [markdown]
# # Decision Making (Exercises, Part 2)

# %% [markdown]
# ## Exercise 41 -  Classifying Triangles
#
# A triangle can be classified based on the lengths of its sides as equilateral, isosceles or
# scalene. All three sides of an equilateral triangle have the same length. An isosceles
# triangle has two sides that are the same length, and a third side that is a different
# length. If all of the sides have different lengths then the triangle is scalene.
# Write a program that reads the lengths of the three sides of a triangle from the
# user. Then display a message that states the triangle’s type (21 lines).

# %%
# Asks the user to enter the length of the sides of the triangle
a = float(input("Enter the length of the first side of the triangle: "))
b = float(input("Enter the length of the second side of the triangle: "))
c = float(input("Enter the length of the third side of the triangle: "))

# Determines which statement is to be displayed based on the user's input
if a == b and b == c:
    print("This is an equilateral triangle.")
elif a == b or b == c or a == c:
    print("This is an isosceles triangle.")
else:
    print("This is a scalene triangle.")
# Out:
# Enter the length of the first side of the triangle: 5
# Enter the length of the second side of the triangle: 7
# Enter the length of the third side of the triangle: 9
# This is a scalene triangle.

# %% [markdown]
# ## Exercise 42 -  Note to Frequency
#
# The following table lists an octave of music notes, beginning with middle C, along
# with their frequencies.
#
# ![table_2.png](attachment:table_2.png)
#
# Begin by writing a program that reads the name of a note from the user and
# displays the note’s frequency. Your program should support all of the notes listed
# previously.
# Once you have your program working correctly for the notes listed previously
# you should add support for all of the notes from C0 to C8. While this could be
# done by adding many additional cases to your if statement, such a solution is
# cumbersome, inelegant and unacceptable for the purposes of this exercise. Instead,
# you should exploit the relationship between notes in adjacent octaves. In particular, the frequency of any note in octave $n$ is half the frequency of the corresponding note in octave $n + 1$. By using this relationship, you should be able to
# add support for the additional notes without adding additional cases to your if
# statement (39 lines).
#
# **Hint: You will want to access the characters in the note entered by the user
# individually when completing this exercise. Begin by separating the letter from
# the octave. Then compute the frequency for that letter in the fourth octave using
# the data in the table above. Once you have this frequency you should divide it
# by $2^{4−x}$ , where $x$ is the octave number entered by the user. This will halve or
# double the frequency the correct number of times.**

# %%
# Asks the user to enter the note and the octave number
note = input("Enter the note: ")
x = int(input("Enter the octave number: "))

# Determines which action is to be taken and statement to be displayed based on the input
if note == "C":
    f = 261.63 / 2 ** (4-x)
    print("The frequency of C" + str(x) + " is:",f, "hz")
elif note == "D":
    f = 293.66 / 2 ** (4-x)
    print("The frequency of D" + str(x) + " is:",f, "hz")
elif note == "E":
    f = 329.63 / 2 ** (4-x)
    print("The frequency of E" + str(x) + " is:",f, "hz")
elif note == "F":
    f = 349.23 / 2 ** (4-x)
    print("The frequency of F" + str(x) + " is:",f, "hz")
elif note == "G":
    f = 392.00 / 2 ** (4-x)
    print("The frequency of G" + str(x) + " is:",f, "hz")
elif note == "A":
    f = 440.00 / 2 ** (4-x)
    print("The frequency of A" + str(x) + " is:",f, "hz")
elif note == "B":
    f = 493.88 / 2 ** (4-x)
    print("The frequency of B" + str(x) + " is:", f, "hz")
# Out:
# Enter the note: C
# Enter the octave number: 3
# The frequency of C3 is: 130.815 hz

# %% [markdown]
# ## Exercise 43: Frequency to Note
#
# In the previous question you converted from a note’s name to its frequency. In this
# question you will write a program that reverses that process. Begin by reading a
# frequency from the user. If the frequency is within one Hertz of a value listed in
# the table in the previous question then report the name of the corresponding note.
# Otherwise report that the frequency does not correspond to a known note. In this
# exercise you only need to consider the notes listed in the table. There is no need to
# consider notes from other octaves (42 lines).

# %%
# Asks the user to enter the frequency
f = float(input("Enter the frequency(in hz): "))

# Determines which statement is to be displayed based on the input
if f >= 260.63 and f <= 262.63:
    print("The frequency corresponds to the note C4")
elif f >= 292.66 and f <= 294.66:
    print("The frequency corresponds to the note D4")
elif f >= 328.63 and f <= 330.63:
    print("The frequency corresponds to the note E4")
elif f >= 348.23 and f <= 350.23:
    print("The frequency corresponds to the note F4")
elif f >= 391.00 and f <= 393.00:
    print("The frequency corresponds to the note G4")
elif f >= 439.00 and f <= 441.00:
    print("The frequency corresponds to the note A4")
elif f >= 492.88 and f <= 494.88:
    print("The frequency corresponds to the note B4")
else:
    print("The frequency does not correspond to any note within the range.")
# Out:
# Enter the frequency(in hz): 300
# The frequency does not correspond to any note within the range.

# %% [markdown]
# ## Exercise 44 -  Faces on Money
#
# It is common for images of a country’s previous leaders, or other individuals of historical significance, to appear on its money. The individuals that appear on banknotes
# in the United States are listed in below.
#
# ![table_3.png](attachment:table_3.png)
#
# Write a program that begins by reading the denomination of a banknote from the
# user. Then your program should display the name of the individual that appears on the
# banknote of the entered amount. An appropriate error message should be displayed
# if no such note exists (31 lines).
#
# **While two dollar banknotes are rarely seen in circulation in the United States,
# they are legal tender that can be spent just like any other denomination. The
# United States has also issued banknotes in denominations of $ 500, $ 1,000,
# $ 5,000, and $ 10,000 for public use. However, high denomination banknotes
# have not been printed since 1945 and were officially discontinued in 1969. As
# a result, we will not consider them in this exercise.**

# %%
# Asks the user to enter the denomination
money = int(input("Enter the money denomination(in USD): "))

# Decides which statement is to be dislayed based on the input
if money == 1:
    print("The face in the $" + str(money) + " banknote is George Washington.")
elif money == 2:
    print("The face in the $" + str(money) + " banknote is Thomas Jefferson.")
elif money == 5:
    print("The face in the $" + str(money) + " banknote is Abraham Lincoln.")
elif money == 10:
    print("The face in the $" + str(money) + " banknote is Alexander Hamilton.")
elif money == 20:
    print("The face in the $" + str(money) + " banknote is Andrew Jackson.")
elif money == 50:
    print("The face in the $" + str(money) + " banknote is Ulysees S. Grant.")
elif money == 100:
    print("The face in the $" + str(money) + " banknote is Benjamin Franklin.")
else:
    print("No banknote of that denomination is existing.")
# Out:
# Enter the money denomination(in USD): 300
# No banknote of that denomination is existing.

# %% [markdown]
# ## Exercise 45 -  Date to Holiday Name
#
# Canada has three national holidays which fall on the same dates each year.
#
# ![table_4.png](attachment:table_4.png)
#
# Write a program that reads a month and day from the user. If the month and day
# match one of the holidays listed previously then your program should display the
# holiday’s name. Otherwise your program should indicate that the entered month and
# day do not correspond to a fixed-date holiday (18 lines).
#
# **Canada has two additional national holidays, Good Friday and Labour Day,
# whose dates vary from year to year. There are also numerous provincial and
# territorial holidays, some of which have fixed dates, and some of which have
# variable dates. We will not consider any of these additional holidays in this
# exercise.**

# %%
# Asks the user to enter the month and the day
date = input("Enter the date(month and day only): ")

# Determines which statement is to be displayed based on the input
if date == "January 1":
    print(date,"is New Year's Day.")
elif date == "July 1":
    print(date,"is Canada Day.")
elif date == "December 25":
    print(date,"is Christmas Day.")
else:
    print("No corresponding holiday on this date.")
# Out:
# Enter the date(month and day only): August 1
# No corresponding holiday on this date.

# %% [markdown]
# ## Exercise 46 - What Color Is That Square?
#
# Positions on a chess board are identified by a letter and a number. The letter identifies
# the column, while the number identifies the row, as shown below:
#
# ![table_5.png](attachment:table_5.png)
#
# Write a program that reads a position from the user. Use an if statement to
# determine if the column begins with a black square or a white square. Then use
# modular arithmetic to report the color of the square in that row. For example, if the
# user enters a1 then your program should report that the square is black. If the user
# enters d5 then your program should report that the square is white. Your program
# may assume that a valid position will always be entered. It does not need to perform
# any error checking (22 lines).

# %%
# Asks the user to enter the position
location = input("Enter the position: ")

# Extracts the letter character in load them into variable "letter"
letter = location[0]

# Determines whether the number character is odd or even (even if div=0, odd if div=1)
div = int(location[1]) % 2

# Determines which color of the square based on the input
if (letter == "a" or letter == "c" or letter == "e" or letter == "g") and div == 0:
    print("The color of the square is white.")
elif (letter == "b" or letter == "d" or letter == "f" or letter == "h") and div == 1:
    print("The color of the square is white.")
elif (letter == "a" or letter == "c" or letter == "e" or letter == "g") and div == 1:
    print("The color of the square is black.")
elif (letter == "b" or letter == "d" or letter == "f" or letter == "h") and div == 0:
    print("The color of the square is black.")
# Out:
# Enter the position: h2
# The color of the square is black.

# %% [markdown]
# ## Exercise 47: Season from Month and Day
#
# The year is divided into four seasons: spring, summer, fall (or autumn) and winter.
# While the exact dates that the seasons change vary a little bit from year to year
# because of the way that the calendar is constructed, we will use the following dates
# for this exercise:
#
# ![table_6.png](attachment:table_6.png)
#
# Create a program that reads a month and day from the user. The user will
# enter the name of the month as a string, followed by the day within the month as an
# integer. Then your program should display the season associated with the date that
# was entered(43 lines).

# %%
# Asks the user to input the month and the day
month = input("Enter the month name: ")
day = int(input("Enter the day number: "))

# Determines which season will be displayed based on the input
if month == "March" and day == 20:
    print("Today is the first day of spring.")
elif month == "June" and day == 21:
    print("Today is the first day of summer.")
elif month == "September" and day == 22:
    print("Today is the first day of fall.")
elif month == "December" and day == 20:
    print("Today is the first day of winter.")
# Out:
# Enter the month name: March
# Enter the day number: 20
# Today is the first day of spring.

# %% [markdown]
# ## Exercise 48 - Birth Date to Astrological Sign
#
# The horoscopes commonly reported in newspapers use the position of the sun at the
# time of one’s birth to try and predict the future. This system of astrology divides the
# year into twelve zodiac signs, as outline in the table below:
#
# ![table%207.png](attachment:table%207.png)
#
# Write a program that asks the user to enter his or her month and day of birth. Then
# your program should report the user’s zodiac sign as part of an appropriate output
# message (47 lines).

# %%
# Asks the user to enter his/her birthdate
birthdate = input("Enter your birthdate: ")

# Splits the month and the day number and put them in their corresponding variables
month = birthdate.split()[0]
day = int(birthdate.split()[1])

# Determine which zodiac sign is to be displayed based on the input birthdate
if (month == "December" and (day >= 22 and day <= 31)) or (month == "January" and (day >= 1 and day <= 19)):
    print("Your zodiac sign is Capricorn.")
elif (month == "January" and (day >= 20 and day <= 31)) or (month == "February" and (day >= 1 and day <= 18)):
    print("Your zodiac sign is Aquarius.")
elif (month == "February" and (day >= 19 and day <= 29)) or (month == "March" and (day >= 1 and day <= 20)):
    print("Your zodiac sign is Pisces.")
elif (month == "March" and (day >= 21 and day <= 31)) or (month == "April" and (day >= 1 and day <= 19)):
    print("Your zodiac sign is Aries.")
elif (month == "April" and (day >= 20 and day <= 30)) or (month == "May" and (day >= 1 and day <= 20)):
    print("Your zodiac sign is Taurus.")
elif (month == "May" and (day >= 21 and day <= 31)) or (month == "June" and (day >= 1 and day <= 20)):
    print("Your zodiac sign is Gemini.")
elif (month == "June" and (day >= 21 and day <= 30)) or (month == "July" and (day >= 1 and day <= 22)):
    print("Your zodiac sign is Cancer.")
elif (month == "July" and (day >= 23 and day <= 31)) or (month == "August" and (day >= 1 and day <= 22)):
    print("Your zodiac sign is Leo.")
elif (month == "August" and (day >= 23 and day <= 31)) or (month == "September" and (day >= 1 and day <= 22)):
    print("Your zodiac sign is Virgo.")
elif (month == "September" and (day >= 23 and day <= 30)) or (month == "October" and (day >= 1 and day <= 22)):
    print("Your zodiac sign is Libra.")
elif (month == "October" and (day >= 23 and day <= 31)) or (month == "November" and (day >= 1 and day <= 21)):
    print("Your zodiac sign is Scorpio.")
elif (month == "November" and (day >= 22 and day <= 30)) or (month == "December" and (day >= 1 and day <= 21)):
    print("Your zodiac sign is Sagittarius.")
# Out:
# Enter your birthdate: November 21
# Your zodiac sign is Scorpio.

# %% [markdown]
# ## Exercise 49 - Chinese Zodiac
#
# The Chinese zodiac assigns animals to years in a 12 year cycle. One 12 year cycle is
# shown in the table below. The pattern repeats from there, with 2012 being another
# year of the dragon, and 1999 being another year of the hare.
#
# ![Table_8.png](attachment:Table_8.png)
#
# Write a program that reads a year from the user and displays the animal associated
# with that year. Your program should work correctly for any year greater than or equal
# to zero, not just the ones listed in the table (40 lines).

# %%
# Asks the user to enter his birth year
year = int(input("Enter your birth year: "))

# Gets the remainder of year divided by 12
div = year % 12

# Determine which Chinese zodiac sign which is to be displayed base on the input
if year < 0:
    print("Value Error: Invalid Year")
else:
    if div == 0:
        print("Your Chinese zodiac sign is Monkey.")
    elif div == 1:
        print("Your Chinese zodiac sign is Rooster.")
    elif div == 2:
        print("Your Chinese zodiac sign is Dog.")
    elif div == 3:
        print("Your Chinese zodiac sign is Pig.")
    elif div == 4:
        print("Your Chinese zodiac sign is Rat.")
    elif div == 5:
        print("Your Chinese zodiac sign is Ox.")
    elif div == 6:
        print("Your Chinese zodiac sign is Tiger.")
    elif div == 7:
        print("Your Chinese zodiac sign is Hare.")
    elif div == 8:
        print("Your Chinese zodiac sign is Dragon.")
    elif div == 9:
        print("Your Chinese zodiac sign is Snake.")
    elif div == 10:
        print("Your Chinese zodiac sign is Horse.")
    elif div == 11:
        print("Your Chinese zodiac sign is Sheep.")
# Out:
# Enter your birth year: 2
# Your Chinese zodiac sign is Dog.

# %% [markdown]
# ## Exercise 50: Richter Scale
#
# The following table contains earthquake magnitude ranges on the Richter scale and
# their descriptors:
#
# ![table_10.png](attachment:table_10.png)
#
# Write a program that reads a magnitude from the user and displays the appropriate
# descriptor as part of a meaningful message. For example, if the user enters 5.5 then
# your program should indicate that a magnitude 5.5 earthquake is considered to be a
# moderate earthquake (30 lines).

# %%
# Asks the person to enter the magnitude
magnitude = float(input("Enter the magnitude of the earthquake: "))

# Determines which discriptor is to be displayed based on the input
if magnitude < 2.0:
    print("It is a micro earthquake.")
elif magnitude == 2.0 or magnitude < 3.0:
    print("It is a very minor earthquake.")
elif magnitude == 3.0 or magnitude < 4.0:
    print("It is a minor earthquake.")
elif magnitude == 4.0 or magnitude < 5.0:
    print("It is a light earthquake.")
elif magnitude == 5.0 or magnitude < 6.0:
    print("It is a moderate earthquake.")
elif magnitude == 6.0 or magnitude < 7.0:
    print("It is a strong earthquake!")
elif magnitude == 7.0 or magnitude < 8.0:
    print("It is a major earthquake!")
elif magnitude == 8.0 or magnitude < 10.0:
    print("It is a great earthquake!")
else:
    print("It is a meteoric earthquake!")
# Out:
# Enter the magnitude of the earthquake: 10.1
# It is a meteoric earthquake!
